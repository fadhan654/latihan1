# %% [markdown]
# <a href="https://colab.research.google.com/github/fadhan654/latihan1/blob/main/DataVisualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygal
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.5/129.5 kB 2.5 MB/s eta 0:00:00
# ...

# %%
# !pip install cairosvg
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 1.8 MB/s eta 0:00:00
# ...

# %%
import pygal
from IPython.display import Image

# Create a radar chart object
dot_chart = pygal.Radar()

# Set the title of the chart
dot_chart.title = 'Total Precipitation (mm)'

# Set the labels for the x-axis
dot_chart.x_labels = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# Add data for each year
dot_chart.add('2012', [67.81, 25.41, 30.72, 78.49, 87.12, 119.62, 98.56, 78.23, 86.11, 66.53, 25.65, 149.59])
dot_chart.add('2013', [28.68, 120.89, 41.90, 34.80, 81.54, 266.70, 91.67, 46.73, 56.14, 15.48, 69.09, 117.35])
dot_chart.add('2014', [82.31, 96.01, 102.36, 82.30, 72.63, 66.55, 116.07, 44.44, 17.77, 148.06, 133.86, 166.61])

# Render the chart to a PNG file
dot_chart.render_to_png('radar.png')

# Display the image in Jupyter Notebook
Image('radar.png')

# %%
import pygal
from IPython.display import Image

# Create a gauge chart object
gauge_chart = pygal.Gauge()

# Set the title of the chart
gauge_chart.title = 'Total Precipitation (mm)'

# Set the range for the gauge
gauge_chart.range = [0, 1000]

# Add data for each year
gauge_chart.add('2012', 765)
gauge_chart.add('2013', 860)
gauge_chart.add('2014', 962)

# Render the chart to a PNG file
gauge_chart.render_to_png('gauge.png')

# Display the image in Jupyter Notebook
Image('gauge.png')

# %%
# importing pygal
import pygal
import numpy


# creating the chart object
horizontal_chart = pygal.HorizontalBar()

# naming the title
horizontal_chart.title = 'Horizontal Chart'

# Random data
horizontal_chart.add('A', numpy.random.rand(10))
horizontal_chart.add('B', numpy.random.rand(10))
horizontal_chart.add('C', numpy.random.rand(10))
horizontal_chart.add('D', numpy.random.rand(10))

horizontal_chart

# %%
# !pip install pygal_maps_world
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.8/270.8 kB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pygal_maps_world: filename=pygal_maps_world-1.0.2-py3-none-any.whl size=278544 sha256=76ca072a3f42c0639748d7fbcb36688d614ea43bebe67b6b12e65d39e44455c4
#   Stored in directory: /root/.cache/pip/wheels/d7/c6/6a/0b0546db76e2a8ddf6f4426ba7172755470e7139467676b9ef
# Successfully built pygal_maps_world
# ...

# %%
from pygal_maps_world.maps import World
from IPython.display import Image

# Create a world map chart object
worldmap_chart = World()
worldmap_chart.force_uri_protocol = 'http'
worldmap_chart.title = 'Top 20 Most Populated Countries'

# Add population data for the top 20 most populated countries
worldmap_chart.add('Population', {
    'cn': 1393783836,  # China
    'in': 1267401849,  # India
    'us': 322583006,   # United States
    'id': 252812245,   # Indonesia
    'br': 202033670,   # Brazil
    'pk': 185132926,   # Pakistan
    'ng': 178516904,   # Nigeria
    'bd': 158512570,   # Bangladesh
    'ru': 142467651,   # Russia
    'jp': 126999808,   # Japan
    'mx': 123799215,   # Mexico
    'ph': 180096496,   # Philippines
    'et': 96506031,    # Ethiopia
    'vn': 92547959,    # Vietnam
    'eg': 83386739,    # Egypt
    'de': 82652256,    # Germany
    'ir': 78470222,    # Iran
    'tr': 75837020,    # Turkey
    'cg': 69360118,    # Congo
    'th': 67222972     # Thailand
})

# Render the chart to a PNG file
worldmap_chart.render_to_png('map.png')

# Display the image in Jupyter Notebook
Image('map.png')

# %%
import pygal
from IPython.display import SVG, Image

# Create a scatter plot (XY chart)
xy_chart = pygal.XY(stroke=False)
xy_chart.title = 'Mean Temp vs Mean Humidity'
xy_chart.x_title = 'Mean Temp (C)'
xy_chart.y_title = 'Mean Humidity (%)'

# Add data
xy_chart.add('Mar', [
    (11, 62), (13, 66), (8, 79), (4, 66),
    (9, 58), (6, 61), (10, 76), (11, 66),
    (14, 59), (14, 58), (16, 64), (14, 69),
    (7, 44), (9, 59), (16, 56), (14, 84),
    (11, 93), (7, 79), (12, 77), (12, 57),
    (18, 59), (15, 61), (13, 67), (8, 58),
    (7, 49), (5, 44), (9, 51), (14, 77),
    (14, 79), (12, 48), (15, 48)
])
xy_chart.add('Oct', [
    (22, 68), (22, 70), (22, 81), (13, 55),
    (13, 57), (17, 66), (20, 68), (23, 74),
    (23, 74), (23, 72), (24, 74), (23, 74),
    (23, 72), (19, 77), (17, 68), (15, 76),
    (17, 65), (18, 67), (15, 67), (14, 69),
    (17, 70), (14, 56), (13, 63), (15, 61),
    (16, 62), (19, 65), (19, 70), (18, 73),
    (15, 83), (12, 61), (10, 71)
])

# Render the chart to an SVG file
xy_chart.render_to_file('scatter.svg')

# Convert SVG to PNG if needed
import cairosvg
cairosvg.svg2png(url='scatter.svg', write_to='scatter.png')

# Display the chart in Jupyter Notebook
Image('scatter.png')

# %%
import pygal
from IPython.display import Image

# Create a Pie chart object
pie_chart = pygal.Pie()

# Set the title of the chart
pie_chart.title = 'Population of Continents (in millions)'

# Add data for each continent
pie_chart.add('Asia', 4397)
pie_chart.add('Africa', 1171)
pie_chart.add('Europe', 742)
pie_chart.add('South America', 630)
pie_chart.add('North America', 357)  # Corrected this line
pie_chart.add('Oceania', 40)          # Corrected this line

# Render the chart to a PNG file
pie_chart.render_to_png('pie.png')

# Display the image in Jupyter Notebook
Image('pie.png')

# %%
import pygal
from IPython.display import Image

# Create a box plot object
box_plot = pygal.Box()

# Set the title of the box plot
box_plot.title = 'Total Precipitation (mm)'

# Add data for each year
box_plot.add('2012', [67.81, 25.41, 30.72, 78.49, 87.12, 119.62, 98.56, 78.23, 86.11, 66.53, 25.65, 149.59])
box_plot.add('2013', [28.68, 120.89, 41.90, 34.80, 81.54, 266.70, 91.67, 46.73, 56.14, 15.48, 69.09, 117.35])
box_plot.add('2014', [82.31, 96.01, 102.36, 82.30, 72.63, 66.55, 116.07, 44.44, 17.77, 148.06, 133.86, 166.61])

# Render the box plot to a PNG file
box_plot.render_to_png('box.png')

# Display the image in Jupyter Notebook
Image('box.png')
